# %%
from sqlalchemy import create_engine
engine = create_engine("mysql+pymysql://root:991227@localhost/test",echo = True)

# %%
print(engine)
print(type(engine))
# Out:
# Engine(mysql+pymysql://root:***@localhost/test)
# <class 'sqlalchemy.engine.base.Engine'>

# %%
from sqlalchemy import Table,Column,Integer,String,MetaData
meta = MetaData()

students = Table(
    'students',meta,
    Column('id',Integer,primary_key=True),
    Column('name',String(20)),
    Column('lastname',String(20))
)

meta.create_all(engine)
# Out:
# 2026-03-31 17:38:49,379 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2026-03-31 17:38:49,381 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-03-31 17:38:49,382 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2026-03-31 17:38:49,383 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-03-31 17:38:49,385 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2026-03-31 17:38:49,385 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-03-31 17:38:49,386 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-03-31 17:38:49,387 INFO sqlalchemy.engine.Engine DESCRIBE `test`.`students`
# 2026-03-31 17:38:49,388 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-03-31 17:38:49,391 INFO sqlalchemy.engine.Engine
# CREATE TABLE students (
# 	id INTEGER NOT NULL AUTO_INCREMENT,
# 	name VARCHAR(20),
# 	lastname VARCHAR(20),
# 	PRIMARY KEY (id)
# )
#
#
# 2026-03-31 17:38:49,392 INFO sqlalchemy.engine.Engine [no key 0.00100s] {}
# ...

# %%
#使用 SQLAlchemy 的核心技术执行 INSERT 查询的完整代码片段 
from sqlalchemy import create_engine, MetaData, Table, Column, Integer, String
engine = create_engine("mysql+pymysql://root:991227@localhost/test",echo = True)
meta = MetaData()

students = Table(
   'students', meta, 
   Column('id', Integer, primary_key = True), 
   Column('name', String), 
   Column('lastname', String), 
)

ins = students.insert()
ins = students.insert().values(name = 'Ravi', lastname = 'Kapoor')
conn = engine.connect()
result = conn.execute(ins)
conn.commit()
conn.close()
# Out:
# 2026-03-31 17:59:12,896 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2026-03-31 17:59:12,897 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-03-31 17:59:12,899 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2026-03-31 17:59:12,899 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-03-31 17:59:12,900 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2026-03-31 17:59:12,901 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-03-31 17:59:12,902 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-03-31 17:59:12,903 INFO sqlalchemy.engine.Engine INSERT INTO students (name, lastname) VALUES (%(name)s, %(lastname)s)
# 2026-03-31 17:59:12,903 INFO sqlalchemy.engine.Engine [generated in 0.00116s] {'name': 'Ravi', 'lastname': 'Kapoor'}
# 2026-03-31 17:59:12,905 INFO sqlalchemy.engine.Engine COMMIT

# %%
#获取从我们的语句生成的主键值的信息
result.inserted_primary_key
# Out:
# (4,)

# %%
from sqlalchemy import create_engine, MetaData, Table, Column, Integer, String
engine = create_engine("mysql+pymysql://root:991227@localhost/test",echo = True)
meta = MetaData()
conn = engine.connect()
conn.execute(students.insert(), [
   {'name':'Rajiv', 'lastname' : 'Khanna'},
   {'name':'Komal','lastname' : 'Bhandari'},
   {'name':'Abdul','lastname' : 'Sattar'},
   {'name':'Priya','lastname' : 'Rajhans'},
])
conn.commit()
conn.close()
# Out:
# 2026-03-31 18:01:05,373 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2026-03-31 18:01:05,375 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-03-31 18:01:05,376 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2026-03-31 18:01:05,376 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-03-31 18:01:05,378 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2026-03-31 18:01:05,378 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-03-31 18:01:05,381 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-03-31 18:01:05,381 INFO sqlalchemy.engine.Engine INSERT INTO students (name, lastname) VALUES (%(name)s, %(lastname)s)
# 2026-03-31 18:01:05,382 INFO sqlalchemy.engine.Engine [generated in 0.00197s] [{'name': 'Rajiv', 'lastname': 'Khanna'}, {'name': 'Komal', 'lastname': 'Bhandari'}, {'name': 'Abdul', 'lastname': 'Sattar'}, {'name': 'Priya', 'lastname': 'Rajhans'}]
# 2026-03-31 18:01:05,384 INFO sqlalchemy.engine.Engine COMMIT

# %%
from sqlalchemy import create_engine, MetaData, Table, Column, Integer, String
engine = create_engine("mysql+pymysql://root:991227@localhost/test",echo = True)
meta = MetaData()
s = students.select()
conn = engine.connect()
result = conn.execute(s)

for row in result:
   print (row)
# Out:
# 2026-03-31 18:02:56,917 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2026-03-31 18:02:56,918 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-03-31 18:02:56,920 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2026-03-31 18:02:56,921 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-03-31 18:02:56,922 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2026-03-31 18:02:56,923 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-03-31 18:02:56,924 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-03-31 18:02:56,924 INFO sqlalchemy.engine.Engine SELECT students.id, students.name, students.lastname
# FROM students
# 2026-03-31 18:02:56,926 INFO sqlalchemy.engine.Engine [generated in 0.00094s] {}
# (4, 'Ravi', 'Kapoor')
# (5, 'Rajiv', 'Khanna')
# (6, 'Komal', 'Bhandari')
# (7, 'Abdul', 'Sattar')
# (8, 'Priya', 'Rajhans')

# %%
s = students.select().where(students.c.id > 2)
result = conn.execute(s)
for row in result:
    print (row)
# Out:
# 2026-03-31 18:05:32,528 INFO sqlalchemy.engine.Engine SELECT students.id, students.name, students.lastname
# FROM students
# WHERE students.id > %(id_1)s
# 2026-03-31 18:05:32,529 INFO sqlalchemy.engine.Engine [generated in 0.00136s] {'id_1': 2}
# (4, 'Ravi', 'Kapoor')
# (5, 'Rajiv', 'Khanna')
# (6, 'Komal', 'Bhandari')
# (7, 'Abdul', 'Sattar')
# (8, 'Priya', 'Rajhans')

# %%
#SQLAlchemy Core - 使用文本 SQL
from sqlalchemy import text
t = text("select * from students")
result = conn.execute(t)
print(result)
for data in result:
    print(data)
# Out:
# 2026-03-31 18:09:13,559 INFO sqlalchemy.engine.Engine select * from students
# 2026-03-31 18:09:13,561 INFO sqlalchemy.engine.Engine [cached since 44.9s ago] {}
# ...
# (4, 'Ravi', 'Kapoor')
# (5, 'Rajiv', 'Khanna')
# (6, 'Komal', 'Bhandari')
# (7, 'Abdul', 'Sattar')
# (8, 'Priya', 'Rajhans')

# %%
from sqlalchemy.sql import text

s = text("select students.name, students.lastname from students where students.name between :x and :y")
conn.execute(s, {'x':'A', 'y':'L'}).fetchall()
# Out:
# 2026-03-31 18:13:57,940 INFO sqlalchemy.engine.Engine select students.name, students.lastname from students where students.name between %(x)s and %(y)s
# 2026-03-31 18:13:57,941 INFO sqlalchemy.engine.Engine [generated in 0.00097s] {'x': 'A', 'y': 'L'}
# [('Komal', 'Bhandari'), ('Abdul', 'Sattar')]

# %%
stmt=students.update().where(students.c.lastname=='Khanna').values(lastname='Kapoor')
conn.execute(stmt)
conn.commit()
s = students.select()
conn.execute(s).fetchall()
# Out:
# 2026-03-31 18:19:20,054 INFO sqlalchemy.engine.Engine UPDATE students SET lastname=%(lastname)s WHERE students.lastname = %(lastname_1)s
# 2026-03-31 18:19:20,054 INFO sqlalchemy.engine.Engine [generated in 0.00111s] {'lastname': 'Kapoor', 'lastname_1': 'Khanna'}
# 2026-03-31 18:19:20,057 INFO sqlalchemy.engine.Engine COMMIT
# 2026-03-31 18:19:20,061 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-03-31 18:19:20,062 INFO sqlalchemy.engine.Engine SELECT students.id, students.name, students.lastname
# FROM students
# 2026-03-31 18:19:20,063 INFO sqlalchemy.engine.Engine [cached since 983.1s ago] {}
# [(4, 'Ravi', 'Kapoor'),
#  (5, 'Rajiv', 'Kapoor'),
#  (6, 'Komal', 'Bhandari'),
#  (7, 'Abdul', 'Sattar'),
#  (8, 'Priya', 'Rajhans')]

# %%
stmt = students.delete().where(students.c.lastname == 'Kapoor')
conn.execute(stmt)
conn.commit()
s = students.select()
conn.execute(s).fetchall()
# Out:
# 2026-03-31 18:21:30,549 INFO sqlalchemy.engine.Engine DELETE FROM students WHERE students.lastname = %(lastname_1)s
# 2026-03-31 18:21:30,551 INFO sqlalchemy.engine.Engine [cached since 15.87s ago] {'lastname_1': 'Kapoor'}
# 2026-03-31 18:21:30,553 INFO sqlalchemy.engine.Engine COMMIT
# 2026-03-31 18:21:30,556 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-03-31 18:21:30,556 INFO sqlalchemy.engine.Engine SELECT students.id, students.name, students.lastname
# FROM students
# 2026-03-31 18:21:30,557 INFO sqlalchemy.engine.Engine [cached since 1114s ago] {}
# [(6, 'Komal', 'Bhandari'), (7, 'Abdul', 'Sattar'), (8, 'Priya', 'Rajhans')]

# %%
from sqlalchemy import create_engine, MetaData, Table, Column, Integer, String, ForeignKey
engine = create_engine("mysql+pymysql://root:991227@localhost/test",echo = True)
meta = MetaData()

students = Table(
   'students', meta, 
   Column('id', Integer, primary_key = True), 
   Column('name', String(20)), 
   Column('lastname', String(20)), 
)

addresses = Table(
   'addresses', meta, 
   Column('id', Integer, primary_key = True), 
   Column('st_id', Integer, ForeignKey('students.id')), 
   Column('postal_add', String(20)), 
   Column('email_add', String(20)))

meta.create_all(engine)
# Out:
# 2026-03-31 18:26:15,318 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2026-03-31 18:26:15,318 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-03-31 18:26:15,320 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2026-03-31 18:26:15,321 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-03-31 18:26:15,323 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2026-03-31 18:26:15,323 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-03-31 18:26:15,325 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-03-31 18:26:15,325 INFO sqlalchemy.engine.Engine DESCRIBE `test`.`students`
# 2026-03-31 18:26:15,325 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-03-31 18:26:15,329 INFO sqlalchemy.engine.Engine DESCRIBE `test`.`addresses`
# 2026-03-31 18:26:15,329 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-03-31 18:26:15,332 INFO sqlalchemy.engine.Engine
# CREATE TABLE addresses (
# 	id INTEGER NOT NULL AUTO_INCREMENT,
# 	st_id INTEGER,
# 	postal_add VARCHAR(20),
# ...

# %%
from sqlalchemy import create_engine, MetaData, Table, Column, Integer, String
engine = create_engine("mysql+pymysql://root:991227@localhost/test",echo = True)
meta = MetaData()
conn = engine.connect()
addresses = Table(
   'addresses', meta,
   Column('st_id', Integer, primary_key = True),
   Column('postal_add', String(250)),
   Column('email_add', String(250)),
)
conn.execute(addresses.insert(), [
   {'st_id':8,'postal_add':'Komal@qq.com', 'email_add' : 'Bhandari@qq.com'},
   {'st_id':7,'postal_add':'Abdul@qq.com', 'email_add' : 'Sattar@qq.com'},
   {'st_id':6,'postal_add':'Priya@qq.com', 'email_add' : 'Rajhans@qq.com'},
])
conn.commit()
conn.close()
# Out:
# 2026-04-01 10:02:21,718 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2026-04-01 10:02:21,718 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-04-01 10:02:21,722 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2026-04-01 10:02:21,722 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-04-01 10:02:21,723 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2026-04-01 10:02:21,724 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-04-01 10:02:21,726 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-04-01 10:02:21,726 INFO sqlalchemy.engine.Engine INSERT INTO addresses (st_id, postal_add, email_add) VALUES (%(st_id)s, %(postal_add)s, %(email_add)s)
# 2026-04-01 10:02:21,728 INFO sqlalchemy.engine.Engine [generated in 0.00169s] [{'st_id': 8, 'postal_add': 'Komal@qq.com', 'email_add': 'Bhandari@qq.com'}, {'st_id': 7, 'postal_add': 'Abdul@qq.com', 'email_add': 'Sattar@qq.com'}, {'st_id': 6, 'postal_add': 'Priya@qq.com', 'email_add': 'Rajhans@qq.com'}]
# ...

# %%
from sqlalchemy import create_engine,MetaData,Table,Column,Integer,String,ForeignKey
engine = create_engine("mysql+pymysql://root:991227@localhost/test",echo = True)
conn = engine.connect()
meta = MetaData()
students = Table(
   'students', meta, 
   Column('id', Integer, primary_key = True), 
   Column('name', String), 
   Column('lastname', String), 
)

addresses = Table(
   'addresses', meta, 
   Column('id', Integer, primary_key = True), 
   Column('st_id', Integer,ForeignKey('students.id')), 
   Column('postal_add', String), 
   Column('email_add', String)
)
from sqlalchemy import join
from sqlalchemy.sql import select

j = students.join(addresses, students.c.id == addresses.c.st_id)
stmt = select([students]).select_from(j)
result = conn.execute(stmt)
result.fetchall()
conn.commit()
conn.close()

# %% [markdown]
# #SQLAlchemy ORM - 声明映射

# %%
from sqlalchemy import Column, Integer, String
from sqlalchemy import create_engine
engine = create_engine("mysql+pymysql://root:991227@localhost/sqlaichemy",echo = True)
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()

class Customer(Base):
    __tablename__ = 'customers'
    id = Column(Integer, primary_key=True)
    name = Column(String(250))
    lastname = Column(String(250))
    address = Column(String(250))

Base.metadata.create_all(engine)
# Out:
# 2026-04-01 10:23:40,384 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2026-04-01 10:23:40,386 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-04-01 10:23:40,386 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2026-04-01 10:23:40,387 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-04-01 10:23:40,389 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2026-04-01 10:23:40,389 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-04-01 10:23:40,390 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-04-01 10:23:40,392 INFO sqlalchemy.engine.Engine DESCRIBE `sqlaichemy`.`customers`
# 2026-04-01 10:23:40,392 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-04-01 10:23:40,397 INFO sqlalchemy.engine.Engine
# CREATE TABLE customers (
# 	id INTEGER NOT NULL AUTO_INCREMENT,
# 	name VARCHAR(250),
# 	lastname VARCHAR(250),
# 	address VARCHAR(250),
# 	PRIMARY KEY (id)
# )
#
#
# 2026-04-01 10:23:40,397 INFO sqlalchemy.engine.Engine [no key 0.00064s] {}
# ...

# %%
#添加对象

from sqlalchemy import Column,Integer,String
from sqlalchemy import create_engine
engine = create_engine("mysql+pymysql://root:991227@localhost/sqlaichemy",echo = True)
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()
class Customers(Base):
    __tablename__ = 'customers'
    id = Column(Integer, primary_key=True)
    name = Column(String(250))
    address = Column(String(250))
    email   = Column(String(250),unique=True)
Base.metadata.create_all(engine)
from sqlalchemy.orm import sessionmaker
Session = sessionmaker(bind=engine)
session = Session()

# c1 = Customers(name = 'Ravi Kumar', address = 'Station Road Nanded', email = 'ravi@gmail.com')
# session.add(c1)
session.add_all([
   Customers(name = 'Komal Pande', address = 'Koti, Hyderabad', email = 'komal@gmail.com'), 
   Customers(name = 'Rajender Nath', address = 'Sector 40, Gurgaon', email = 'nath@gmail.com'), 
   Customers(name = 'S.M.Krishna', address = 'Budhwar Peth, Pune', email = 'smk@gmail.com')]
)

session.commit()
# Out:
# 2026-04-01 10:37:03,268 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2026-04-01 10:37:03,269 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-04-01 10:37:03,271 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2026-04-01 10:37:03,271 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-04-01 10:37:03,272 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2026-04-01 10:37:03,274 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-04-01 10:37:03,276 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-04-01 10:37:03,276 INFO sqlalchemy.engine.Engine DESCRIBE `sqlaichemy`.`customers`
# 2026-04-01 10:37:03,276 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-04-01 10:37:03,277 INFO sqlalchemy.engine.Engine
# CREATE TABLE customers (
# 	id INTEGER NOT NULL AUTO_INCREMENT,
# 	name VARCHAR(250),
# 	address VARCHAR(250),
# 	email VARCHAR(250),
# 	PRIMARY KEY (id),
# 	UNIQUE (email)
# )
#
#
# 2026-04-01 10:37:03,279 INFO sqlalchemy.engine.Engine [no key 0.00054s] {}
# ...

# %%
from sqlalchemy import Column,Integer,String
from sqlalchemy import create_engine
engine = create_engine("mysql+pymysql://root:991227@localhost/sqlaichemy",echo = True)
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()

from sqlalchemy.orm import sessionmaker
Session = sessionmaker(bind = engine)
session = Session()
result = session.query(Customers).all()
for row in result:
    print ("Name: ",row.name, "Address:",row.address, "Email:",row.email)
# Out:
# 2026-04-01 10:42:26,979 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2026-04-01 10:42:26,981 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-04-01 10:42:26,981 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2026-04-01 10:42:26,983 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-04-01 10:42:26,985 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2026-04-01 10:42:26,986 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-04-01 10:42:26,987 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-04-01 10:42:26,987 INFO sqlalchemy.engine.Engine SELECT customers.id AS customers_id, customers.name AS customers_name, customers.address AS customers_address, customers.email AS customers_email
# FROM customers
# 2026-04-01 10:42:26,989 INFO sqlalchemy.engine.Engine [generated in 0.00060s] {}
# Name:  Komal Pande Address: Koti, Hyderabad Email: komal@gmail.com
# Name:  Rajender Nath Address: Sector 40, Gurgaon Email: nath@gmail.com
# ...

# %%
from sqlalchemy import Column,Integer,String
from sqlalchemy import create_engine
engine = create_engine("mysql+pymysql://root:991227@localhost/sqlaichemy",echo = True)
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()

from sqlalchemy.orm import sessionmaker
Session = sessionmaker(bind = engine)
session = Session()
result = session.query(Customers).get(2)
print ("Name: ",result.name, "Address:",result.address, "Email:",result.email)
# Out:
# 2026-04-01 10:43:44,439 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2026-04-01 10:43:44,440 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-04-01 10:43:44,442 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2026-04-01 10:43:44,443 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-04-01 10:43:44,444 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2026-04-01 10:43:44,445 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-04-01 10:43:44,446 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-04-01 10:43:44,449 INFO sqlalchemy.engine.Engine SELECT customers.id AS customers_id, customers.name AS customers_name, customers.address AS customers_address, customers.email AS customers_email
# FROM customers
# WHERE customers.id = %(pk_1)s
# 2026-04-01 10:43:44,450 INFO sqlalchemy.engine.Engine [generated in 0.00076s] {'pk_1': 2}
# Name:  Rajender Nath Address: Sector 40, Gurgaon Email: nath@gmail.com
# ...

# %%
from sqlalchemy import Column,Integer,String
from sqlalchemy import create_engine
engine = create_engine("mysql+pymysql://root:991227@localhost/sqlaichemy",echo = True)
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()

from sqlalchemy.orm import sessionmaker
Session = sessionmaker(bind = engine)
session = Session()
result = session.query(Customers).get(2)
print("*********")
print ("Name: ",result.name, "Address:",result.address, "Email:",result.email)
print("*********")
result.address = 'Banjara Hills Secunderabad'
session.commit()
print ("Name: ",result.name, "Address:",result.address, "Email:",result.email)
print("*********")
# Out:
# 2026-04-01 10:45:11,167 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2026-04-01 10:45:11,168 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-04-01 10:45:11,170 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2026-04-01 10:45:11,170 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-04-01 10:45:11,172 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2026-04-01 10:45:11,173 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-04-01 10:45:11,175 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-04-01 10:45:11,176 INFO sqlalchemy.engine.Engine SELECT customers.id AS customers_id, customers.name AS customers_name, customers.address AS customers_address, customers.email AS customers_email
# FROM customers
# WHERE customers.id = %(pk_1)s
# 2026-04-01 10:45:11,178 INFO sqlalchemy.engine.Engine [generated in 0.00118s] {'pk_1': 2}
# *********
# Name:  Rajender Nath Address: Sector 40, Gurgaon Email: nath@gmail.com
# *********
# ...

# %%
from sqlalchemy import Column,Integer,String
from sqlalchemy import create_engine
engine = create_engine("mysql+pymysql://root:991227@localhost/sqlaichemy",echo = True)
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()

from sqlalchemy.orm import sessionmaker
Session = sessionmaker(bind = engine)
session = Session()
result = session.query(Customers).filter(Customers.id > 2)
for row in result:
    print ("Name: ",row.name, "Address:",row.address, "Email:",row.email)
# Out:
# 2026-04-01 10:53:03,464 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2026-04-01 10:53:03,464 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-04-01 10:53:03,465 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2026-04-01 10:53:03,465 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-04-01 10:53:03,467 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2026-04-01 10:53:03,467 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-04-01 10:53:03,468 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-04-01 10:53:03,470 INFO sqlalchemy.engine.Engine SELECT customers.id AS customers_id, customers.name AS customers_name, customers.address AS customers_address, customers.email AS customers_email
# FROM customers
# WHERE customers.id > %(id_1)s
# 2026-04-01 10:53:03,470 INFO sqlalchemy.engine.Engine [generated in 0.00059s] {'id_1': 2}
# Name:  S.M.Krishna Address: Budhwar Peth, Pune Email: smk@gmail.com
# ...

# %%
#SQLAlchemy ORM - 建立关系
from sqlalchemy import create_engine, ForeignKey, Column, Integer, String
engine = create_engine("mysql+pymysql://root:991227@localhost/sqlaichemy",echo = True)
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()
from sqlalchemy.orm import relationship

class Customer(Base):
   __tablename__ = 'customers'

   id = Column(Integer, primary_key = True)
   name = Column(String(250))
   address = Column(String(250))
   email = Column(String(250))


class Invoice(Base):
   __tablename__ = 'invoices'
   
   id = Column(Integer, primary_key = True)
   custid = Column(Integer, ForeignKey('customers.id'))
   invno = Column(Integer)
   amount = Column(Integer)
   customer = relationship("Customer", back_populates = "invoices")


Customer.invoices = relationship("Invoice", order_by = Invoice.id, back_populates = "customer")
Base.metadata.create_all(engine)
# Out:
# 2026-04-01 11:06:41,944 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2026-04-01 11:06:41,944 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-04-01 11:06:41,945 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2026-04-01 11:06:41,947 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-04-01 11:06:41,948 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2026-04-01 11:06:41,948 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-04-01 11:06:41,950 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-04-01 11:06:41,951 INFO sqlalchemy.engine.Engine DESCRIBE `sqlaichemy`.`customers`
# 2026-04-01 11:06:41,951 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-04-01 11:06:41,955 INFO sqlalchemy.engine.Engine DESCRIBE `sqlaichemy`.`invoices`
# 2026-04-01 11:06:41,956 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-04-01 11:06:41,959 INFO sqlalchemy.engine.Engine COMMIT
# ...

# %%
c1 = Customer(name = "Gopal Krishna", address = "Bank Street Hydarebad", email = "gk@gmail.com")
c1.invoices = [Invoice(invno = 10, amount = 15000), Invoice(invno = 14, amount = 3850)]
from sqlalchemy.orm import sessionmaker
Session = sessionmaker(bind = engine)
session = Session()
session.add(c1)
session.commit()
# Out:
# 2026-04-01 11:10:43,787 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-04-01 11:10:43,789 INFO sqlalchemy.engine.Engine INSERT INTO customers (name, address, email) VALUES (%(name)s, %(address)s, %(email)s)
# 2026-04-01 11:10:43,790 INFO sqlalchemy.engine.Engine [generated in 0.00079s] {'name': 'Gopal Krishna', 'address': 'Bank Street Hydarebad', 'email': 'gk@gmail.com'}
# 2026-04-01 11:10:43,793 INFO sqlalchemy.engine.Engine INSERT INTO invoices (custid, invno, amount) VALUES (%(custid)s, %(invno)s, %(amount)s)
# 2026-04-01 11:10:43,793 INFO sqlalchemy.engine.Engine [generated in 0.00096s] {'custid': 4, 'invno': 10, 'amount': 15000}
# 2026-04-01 11:10:43,795 INFO sqlalchemy.engine.Engine INSERT INTO invoices (custid, invno, amount) VALUES (%(custid)s, %(invno)s, %(amount)s)
# 2026-04-01 11:10:43,795 INFO sqlalchemy.engine.Engine [cached since 0.003062s ago] {'custid': 4, 'invno': 14, 'amount': 3850}
# 2026-04-01 11:10:43,798 INFO sqlalchemy.engine.Engine COMMIT
